# %%
import pandas as pd
import numpy as np

# %%
all_left_right = ['02to00_0','02to00_1','02to00_2','02to00_3','00toc1_0','00toc1_1','00toc1_2','c1to000_0','c1to000_1','c1to000_2','c1to000_3','000toc4_1','000toc4_2','000toc4_3','c4to0000_0','c4to0000_1','c4to0000_2','c4to0000_3',
                '0000to04_1','0000to04_2','0000to04_3','03to0000_0','03to0000_1','03to0000_2','03to0000_3','0000toc3_0','0000toc3_1','0000toc3_2','c3to000_0','c3to000_1','c3to000_2','c3to000_3','000toc2_0','000toc2_1',
                '000toc2_2','c2to00_0','c2to00_1','c2to00_2','c2to00_3','00to01_0','00to01_1','00to01_2']

right_left = ['03to0000_0','03to0000_1','03to0000_2','03to0000_3', '0000toc3_0','0000toc3_1','0000toc3_2', 'c3to000_0','c3to000_1','c3to000_2','c3to000_3', '000toc2_0','000toc2_1', '000toc2_2','c2to00_0','c2to00_1','c2to00_2','c2to00_3','00to01_0','00to01_1','00to01_2']

left_right = ['02to00_0','02to00_1','02to00_2','02to00_3','00toc1_0','00toc1_1','00toc1_2','c1to000_0','c1to000_1','c1to000_2','c1to000_3','000toc4_1','000toc4_2','000toc4_3','c4to0000_0','c4to0000_1','c4to0000_2','c4to0000_3', '0000to04_1','0000to04_2','0000to04_3']

# %%
print(len(set(left_right)))
# Out:
# 21

# %%
# 중복 제거
all_left_right = list(set(all_left_right))
right_left = list(set(right_left))
left_right = list(set(left_right))

# 어떤 요소가 한 리스트에만 있는지 확인
missing_elements = []

for element in all_left_right:
    if element not in right_left and element not in left_right:
        missing_elements.append(element)

print("빠진 요소:", missing_elements)
# Out:
# 빠진 요소: []

# %%
import numpy as np
a = [155.592, 154.939, 153.582, 155.746, 155.368, 154.973, 154.894, 153.88, 158.138, 155.471]

print('최소 :', np.round(np.min(a),1))
print('최대 :', np.round(np.max(a),1))
print('평균 :', np.round(np.mean(a),1))
print('분산:', np.round(np.var(a),1))
print('표준편차:', round(np.std(a),1))
# Out:
# 최소 : 153.6
# 최대 : 158.1
# 평균 : 155.3
# 분산: 1.4
# 표준편차: 1.2

# %%
df = pd.read_excel("교차로 접근로별 교통량_이마트.xlsx", sheet_name="2303")
df
# Out:
#           접근로명                   시간  교통량  평균속도  보행자수
# 0     금강120동방향  2023-03-01 00:00:00  309    82    25
# 1     금강120동방향  2023-03-01 01:00:00  242    87    26
# 2     금강120동방향  2023-03-01 02:00:00  161    85    11
# 3     금강120동방향  2023-03-01 03:00:00  163    79     5
# 4     금강120동방향  2023-03-01 04:00:00  195    76     8
# ...        ...                  ...  ...   ...   ...
# 2971    중앙공원방향  2023-03-31 19:00:00  899    33    36
# 2972    중앙공원방향  2023-03-31 20:00:00  871    32    29
# 2973    중앙공원방향  2023-03-31 21:00:00  626    32    46
# 2974    중앙공원방향  2023-03-31 22:00:00  441    36    20
# 2975    중앙공원방향  2023-03-31 23:00:00  316    36    27
#
# [2976 rows x 5 columns]

# %%
df_W1 = df[df['접근로명']=='보차도2교방향']
df_W1 = df_W1.reset_index(drop=True)
len(df_W1)
# Out:
# 744

# %%
df_W1['출근시간'] = df_W1['시간'].str[11:]

# %%
len(df_W1)
# Out:
# 744

# %%
df_W1
# Out:
#         접근로명                   시간   교통량  평균속도  보행자수      출근시간
# 0    보차도2교방향  2023-03-01 00:00:00   216    67    21  00:00:00
# 1    보차도2교방향  2023-03-01 01:00:00   178    68    22  01:00:00
# 2    보차도2교방향  2023-03-01 02:00:00   126    65    11  02:00:00
# 3    보차도2교방향  2023-03-01 03:00:00   131    68     6  03:00:00
# 4    보차도2교방향  2023-03-01 04:00:00   119    70     7  04:00:00
# ..       ...                  ...   ...   ...   ...       ...
# 739  보차도2교방향  2023-03-31 19:00:00  1230    32   189  19:00:00
# 740  보차도2교방향  2023-03-31 20:00:00  1108    33   145  20:00:00
# 741  보차도2교방향  2023-03-31 21:00:00   695    33   110  21:00:00
# 742  보차도2교방향  2023-03-31 22:00:00   436    38    76  22:00:00
# 743  보차도2교방향  2023-03-31 23:00:00   314    37    78  23:00:00
#
# [744 rows x 6 columns]

# %%
df_W1.drop(columns=['시간'], inplace=True)

# %%
six = df_W1[(df_W1['출근시간'] == '06:00:00')]
seven = df_W1[(df_W1['출근시간'] == '07:00:00')]
eight = df_W1[(df_W1['출근시간'] == '08:00:00')]

# %%
max_six = six['교통량'].max()
max_seven = seven['교통량'].max()
max_eight = eight['교통량'].max()
max_six, max_seven, max_eight
# Out:
# (286, 485, 679)

# %%
mean_six = six['교통량'].mean()
mean_seven = seven['교통량'].mean()
mean_eight = eight['교통량'].mean()
mean_six, mean_seven, mean_eight
# Out:
# (200.5483870967742, 353.6774193548387, 502.06451612903226)

# %%
max_six + max_seven + max_eight
# Out:
# 1450

# %%
mean_six + mean_seven + mean_eight
# Out:
# 1056.2903225806451
