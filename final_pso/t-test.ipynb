# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
plt.rc('font', family='Malgun Gothic')

# t-검정 수행[9,2,3,4,8,,10,5,15,13,17]
p_values = [0.984539490330249,0.359029258007608, 0.508050713275509, 0.125787921735473, 0.773439940422615, 0.0693236082936613,0.00934364451724434 ,0.0136194065253332, 0.00497047061319539,0.00982402374800444]

# 그래프 그리기
x = np.arange(1, 11)  # x축 값 설정
plt.figure(figsize=(12,6))
plt.plot(x, p_values, marker='o', linestyle='-', color='b', label='p-value')  # p-value를 그래프로 표시
plt.axhline(y=0.05, color='r', linestyle='--', label='유의수준 0.05')  # 유의수준 표시
plt.xlabel('Modified signal cycle count', fontsize=12)
plt.ylabel('p-value', fontsize=12)
plt.title('t-Test Results', fontsize=14)
plt.xticks(np.arange(1,11,1))
plt.legend()  # 범례 추가
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
plt.rc('font', family='Malgun Gothic')
# t-검정 수행[9,2,3,4,8,,10,5,15,13,17]
p_values = [0.984539490330249,0.359029258007608, 0.508050713275509, 0.125787921735473, 0.773439940422615, 0.0693236082936613,0.00934364451724434 ,0.0136194065253332, 0.00497047061319539,0.00982402374800444]
# 그래프 그리기
x = np.arange(1, 11)  # x축 값 설정
plt.figure(figsize=(12, 6))
plt.bar(x, p_values, color='b', label='p-value')  # p-value를 막대 그래프로 표시
plt.axhline(y=0.05, color='r', linestyle='--', label='유의수준 0.05')  # 유의수준 표시
plt.xlabel('Modified signal cycle count', fontsize=12)
plt.ylabel('p-value', fontsize=12)
plt.title('t-Test Results', fontsize=14)
plt.xticks(np.arange(1, 11, 1))
plt.legend()  # 범례 추가
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# t-검정 수행[9,2,3,4,8,,10,5,15,13,17]
p_values = [0.984539490330249,0.359029258007608, 0.508050713275509, 0.125787921735473, 0.773439940422615, 0.0693236082936613,0.00934364451724434 ,0.0136194065253332, 0.00497047061319539,0.00982402374800444]
#p_values = [0.0984539490330249,0.359029258007608, 0.0508050713275509, 0.125787921735473, 0.5773439940422615, 0.0693236082936613,0.00934364451724434 ,0.0136194065253332, 0.00497047061319539,0.00982402374800444]

plt.figure(figsize=(12, 6))
plt.bar(np.arange(1, 11), p_values, color='b', width=0.3, label='p-value')  # 박스 그래프 그리기
plt.axhline(y=0.05, color='r', linestyle='--', label='유의수준 0.05')  # 유의수준 표시

plt.xlabel('Modified signal number', fontsize=12)
plt.ylabel('p-value', fontsize=12)
plt.xticks(np.arange(1, 11, 1))
plt.legend()  # 범례 추가
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1, 11)  # x축 값 설정
# t-검정 수행[9,2,3,4,8,,10,5,15,13,17]
p_values = [0.984539490330249,0.359029258007608, 0.508050713275509, 0.125787921735473, 0.773439940422615, 0.0693236082936613,0.00934364451724434 ,0.0136194065253332, 0.00497047061319539,0.00982402374800444]

plt.scatter(x, p_values, marker='o', color='b')  # 산점도 그래프 그리기
plt.axhline(y=0.05, color='r', linestyle='--')  # 유의수준 표시

plt.xlabel('Modified signal cycle count', fontsize=12)
plt.ylabel('p-value', fontsize=12)
plt.title('t-Test Results', fontsize=14)
plt.xticks(np.arange(1, 11, 1))
plt.show()
